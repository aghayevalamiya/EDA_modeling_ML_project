# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('C:/Users/HP/Desktop/ML Final Project/Ecommerce Customers.csv')
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address  Avg. Session Length  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            34.497268
# 1       4547 Archer Common\nDiazchester, CA 06566-8576            31.926272
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            33.000915
# 3     1414 David Throughway\nPort Jason, OH 22070-1220            34.305557
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...            33.330673
# ..                                                 ...                  ...
# ...

# %%
df.dtypes
# Out:
# Email                    object
# Address                  object
# Avg. Session Length     float64
# Time on App             float64
# Time on Website         float64
# Length of Membership    float64
# Yearly Amount Spent     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Email                   0
# Address                 0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avg. Session Length   500 non-null    float64
#  3   Time on App           500 non-null    float64
#  4   Time on Website       500 non-null    float64
#  5   Length of Membership  500 non-null    float64
#  6   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 27.5+ KB

# %%
mask = np.zeros_like(df.corr(),dtype=bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(df.corr(),annot=True,mask=mask,cmap= 'RdBu_r')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df,kind = "reg")

# %%
fig,ax = plt.subplots(3,2,figsize = (12,8))
sns.histplot(df["Yearly Amount Spent"],ax = ax[0,0],bins = 100,kde = True)
ax[0,0].axvline(df["Yearly Amount Spent"].mean(),ymin = 0,ymax=1 ,color = "r",label = (f"Mean : { df['Yearly Amount Spent'].mean():.2f}"))
ax[0,0].axvline(df["Yearly Amount Spent"].median(),ymin = 0,ymax=1 ,color = "g",label = (f"Median : { df['Yearly Amount Spent'].median():.2f}"))
ax[0,0].legend()
sns.histplot(df["Length of Membership"],ax = ax[0,1],bins = 100,kde = True)
ax[0,1].axvline(df["Length of Membership"].mean(),ymin = 0,ymax=1,color = "r",label = (f"Mean : { df['Length of Membership'].mean():.2f}"))
ax[0,1].axvline(df["Length of Membership"].median(),ymin = 0,ymax=1 ,color = "g",label = (f"Median : { df['Length of Membership'].median():.2f}"))
ax[0,1].legend()
sns.histplot(df["Time on Website"],ax = ax[1,0],bins = 100,kde = True)
ax[1,0].axvline(df["Time on Website"].mean(),ymin = 0,ymax=1 ,color = "r",label = (f"Mean : { df['Time on Website'].mean():.2f}"))
ax[1,0].axvline(df["Time on Website"].median(),ymin = 0,ymax=1 ,color = "g",label = (f"Median : { df['Time on Website'].median():.2f}"))
ax[1,0].legend()
sns.histplot(df["Time on App"],ax = ax[1,1],bins = 100,kde = True)
ax[1,1].axvline(df["Time on App"].mean(),ymin = 0,ymax=100 ,color = "r",label = (f"Mean : { df['Time on App'].mean():.2f}"))
ax[1,1].axvline(df["Time on App"].median(),ymin = -1,ymax=1 ,color = "g",label = (f"Median : { df['Time on App'].median():.2f}"))
ax[1,1].legend()
sns.histplot(df["Avg. Session Length"],ax = ax[2,0],bins = 100,kde = True)
ax[2,0].axvline(df["Avg. Session Length"].mean(),ymin = 0,ymax=100 ,color = "r",label = (f"Mean : { df['Avg. Session Length'].mean():.2f}"))
ax[2,0].axvline(df["Avg. Session Length"].median(),ymin = -1,ymax=1 ,color = "g",label = (f"Median : { df['Avg. Session Length'].median():.2f}"))
ax[2,0].legend()
ax[2,1].remove()

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address  Avg. Session Length  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            34.497268
# 1     4547 Archer Common\nDiazchester, CA 06566-8576            31.926272
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            33.000915
# 3   1414 David Throughway\nPort Jason, OH 22070-1220            34.305557
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...            33.330673
#
#    Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# 0    12.655651        39.577668              4.082621           587.951054
# 1    11.109461        37.268959              2.664034           392.204933
# 2    11.330278        37.110597              4.104543           487.547505
# ...

# %%
x = df.iloc[:, 2:-1]
y = df.iloc[:, -1]
x.head()
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Avg. Session Length', 'Time on App', 'Time on Website',
#         'Length of Membership'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([25.88815047, 38.87046475,  0.47066153, 61.78369021]),
#  '_residues': 39996.707031772436,
#  'rank_': 4,
#  'singular_': array([21.25831108, 20.05858589, 19.17191834, 18.14952141]),
#  'intercept_': -1060.550809427878}

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([438.46488047, 489.66184564, 370.06954182, 513.85905556,
#        495.69799866, 450.8872651 , 458.01303781, 336.66556242,
#        528.51544937, 663.27832045, 559.42244853, 526.02431269,
#        552.20571726, 457.67586172, 450.15607806, 431.65097992,
#        563.58511639, 408.3544021 , 599.61853974, 486.84826713,
#        716.6549357 , 496.79327179, 411.49845257, 556.55139415,
#        551.84576823, 398.18338567, 421.30757533, 395.15395631,
#        548.52797689, 463.48718367, 558.43909629, 505.52726975,
#        505.87531576, 463.94575681, 425.98372415, 401.07293147,
#        503.60337935, 430.34122807, 569.63274312, 421.89472102,
#        487.26750643, 602.37423872, 616.44671936, 589.39491743,
#        449.73449164, 379.9261546 , 558.17328323, 462.72008778,
#        502.16865431, 401.43462335, 523.84624179, 416.80395458,
#        576.87121949, 478.50455228, 457.24801922, 397.67512997,
#        564.86978027, 305.13130975, 562.63197549, 476.33492261,
# ...

# %%
res = pd.DataFrame({'Actual': y_test,
                   'Predicted': y_pred})
res
# Out:
#          Actual   Predicted
# 90   449.070319  438.464880
# 254  482.602467  489.661846
# 283  374.269675  370.069542
# 445  513.153112  513.859056
# 461  502.771075  495.697999
# ..          ...         ...
# 372  385.152338  383.744509
# 56   520.898795  524.168193
# 440  499.140152  500.682688
# 60   616.851523  606.787827
# 208  412.012931  408.805191
#
# [100 rows x 2 columns]

# %%
sns.scatterplot(x='Actual', y='Predicted', data=res)
plt.plot(np.arange(200, 800), np.arange(200, 800), 'r--')

# %%
from sklearn import metrics
print(f"MAE: {metrics.mean_absolute_error(y_test, y_pred)}")
print(f"RMSE: {np.sqrt(metrics.mean_squared_error(y_test, y_pred))}")
print(f"R2: {metrics.r2_score(y_test, y_pred)}")
# Out:
# MAE: 7.64567481588642
# RMSE: 9.637951198511178
# R2: 0.9861924261590183

# %%
import statsmodels.api as sm

# %%
x_sm = sm.add_constant(x)
x_sm.head()
# Out:
#    const  Avg. Session Length  Time on App  Time on Website  \
# 0    1.0            34.497268    12.655651        39.577668
# 1    1.0            31.926272    11.109461        37.268959
# 2    1.0            33.000915    11.330278        37.110597
# 3    1.0            34.305557    13.717514        36.721283
# 4    1.0            33.330673    12.795189        37.536653
#
#    Length of Membership
# 0              4.082621
# 1              2.664034
# 2              4.104543
# 3              3.120179
# 4              4.446308

# %%
x_train, x_test, y_train, y_test = train_test_split(x_sm, y, test_size=0.2, random_state=0)
model = sm.OLS(y_train, x_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Yearly Amount Spent   R-squared:                       0.984
# Model:                             OLS   Adj. R-squared:                  0.984
# Method:                  Least Squares   F-statistic:                     5974.
# Date:                 Sat, 16 Jul 2022   Prob (F-statistic):               0.00
# Time:                         23:03:23   Log-Likelihood:                -1488.6
# No. Observations:                  400   AIC:                             2987.
# Df Residuals:                      395   BIC:                             3007.
# Df Model:                            4
# Covariance Type:             nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
x_new = x.drop(['Time on Website'], axis=1)
x_new.head()
# Out:
#    Avg. Session Length  Time on App  Length of Membership
# 0            34.497268    12.655651              4.082621
# 1            31.926272    11.109461              2.664034
# 2            33.000915    11.330278              4.104543
# 3            34.305557    13.717514              3.120179
# 4            33.330673    12.795189              4.446308

# %%
x_sm_new = sm.add_constant(x_new)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_sm_new, y, test_size=0.2, random_state=0)

# %%
model1 = sm.OLS(y_train, x_train).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Yearly Amount Spent   R-squared:                       0.984
# Model:                             OLS   Adj. R-squared:                  0.984
# Method:                  Least Squares   F-statistic:                     7967.
# Date:                 Sat, 16 Jul 2022   Prob (F-statistic):               0.00
# Time:                         23:03:23   Log-Likelihood:                -1489.0
# No. Observations:                  400   AIC:                             2986.
# Df Residuals:                      396   BIC:                             3002.
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
x = df.iloc[:, 3].values.reshape(-1,1)
y = df.iloc[:, -1].values
x
# Out:
# array([[12.65565115],
#        [11.10946073],
#        [11.33027806],
#        [13.71751367],
#        [12.79518855],
#        [12.02692534],
#        [11.36634831],
#        [12.35195897],
#        [13.38623528],
#        [11.81412829],
#        [13.33897545],
#        [11.584783  ],
#        [10.9612984 ],
#        [12.95922609],
#        [13.14872569],
#        [12.63660605],
#        [11.73386169],
#        [12.01319469],
#        [14.71538754],
#        [13.98959256],
#        [11.36549203],
#        [12.8779837 ],
#        [13.37856278],
#        [11.65757592],
#        [12.8936695 ],
#        [11.76581265],
#        [12.78389178],
#        [13.00781942],
#        [11.98204499],
#        [11.96502   ],
#        [12.30541781],
#        [10.86916381],
#        [13.38749211],
#        [13.10450724],
#        [11.63489325],
#        [11.9363865 ],
#        [11.7550237 ],
#        [11.98441752],
#        [ 9.95497597],
#        [12.48901322],
#        [11.73310622],
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
x_test
# Out:
# array([[12.53035737],
#        [12.32629139],
#        [11.46698422],
#        [11.73299146],
#        [11.37176736],
#        [12.63660605],
#        [12.23565925],
#        [11.30555143],
#        [11.37808709],
#        [12.96576148],
#        [12.63857212],
#        [12.27605698],
#        [11.73066139],
#        [12.80775183],
#        [13.44340599],
#        [13.18518117],
#        [12.66780888],
#        [10.96980287],
#        [12.05026723],
#        [11.98441752],
#        [13.9194944 ],
#        [11.83211223],
#        [11.56811634],
#        [12.93155027],
#        [12.17052542],
#        [10.04731474],
#        [12.8779837 ],
#        [10.44123506],
#        [11.94234087],
#        [11.39520943],
#        [14.03986726],
#        [12.08930957],
#        [11.76117233],
#        [11.72447386],
#        [10.1016322 ],
#        [11.20156988],
#        [11.96689808],
#        [11.48419869],
#        [11.93689516],
#        [13.26676035],
#        [10.73213134],
# ...

# %%
plt.plot(x_train, y_train, 'bo', label='train')
plt.plot(x_test, y_test, 'ro', label='test')
plt.title('Time on App and Yearly amount Spent')
plt.xlabel('Time on App')
plt.ylabel('Yearly Amount spent')
plt.legend()

# %%
regressor1 = LinearRegression()
regressor1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
regressor1.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 1,
#  'coef_': array([39.64988174]),
#  '_residues': 1848864.1520917085,
#  'rank_': 1,
#  'singular_': array([19.70871722]),
#  'intercept_': 23.440364199615658}

# %%
print(f"İntercept -> {regressor1.intercept_}")
print(f"İntercept -> {regressor1.coef_}")
print(f"y = {regressor1.coef_} * x + {regressor1.intercept_}")
# Out:
# İntercept -> 23.440364199615658
# İntercept -> [39.64988174]
# y = [39.64988174] * x + 23.440364199615658

# %%
y_pred = regressor1.predict(x_test)
y_pred
# Out:
# array([520.26755206, 512.17636008, 478.10493242, 488.65208802,
#        474.32959518, 524.48029966, 508.58280645, 471.70414138,
#        474.58017173, 537.53127353, 524.5582541 , 510.18457167,
#        488.55970102, 531.26620959, 556.46982186, 546.23123829,
#        525.71748817, 458.39175069, 501.23203478, 498.62110157,
#        575.34667102, 492.58221483, 482.11480902, 536.1748031 ,
#        506.0002578 , 421.81520543, 534.05089493, 437.43409953,
#        496.95276737, 475.25907048, 580.11944068, 502.78005895,
#        489.76945619, 488.31436619, 423.96888629, 467.58128522,
#        497.92645785, 478.78748412, 496.73684562, 549.46584313,
#        448.96810263, 544.69957367, 542.59756889, 468.96652838,
#        481.46870745, 463.92916832, 567.53402977, 540.45543446,
#        512.28958548, 477.38795629, 522.29724378, 445.1866831 ,
#        531.5691672 , 495.72658249, 491.72873249, 458.05454946,
#        549.94940833, 489.2365368 , 493.94494083, 475.83142406,
# ...

# %%
res = pd.DataFrame({'Actual': y_test,
                   'Predicted': y_pred})
res.head()
# Out:
#         Actual   Predicted
# 0   449.070319  520.267552
# 1   482.602467  512.176360
# 2   374.269675  478.104932
# 3   513.153112  488.652088
# 4   502.771075  474.329595
# ..         ...         ...
# 95  385.152338  470.225510
# 96  520.898795  569.083514
# 97  499.140152  497.890067
# 98  616.851523  518.889093
# 99  412.012931  441.455008
#
# [100 rows x 2 columns]

# %%
plt.plot(x_train, y_train, 'bo', label='training data')
plt.plot(x_train, regressor1.predict(x_train), 'r-', label='training prediction')
plt.title('Training Performance')
plt.xlabel('Time on App')
plt.ylabel('Yearly amount Spent')
plt.legend()

# %%
plt.plot(x_test, y_test, 'bo', label='Test data')
plt.plot(x_test, y_pred, 'r-', label='Test prediction')
plt.title('Test Performance')
plt.xlabel('Time on App')
plt.ylabel('Yearly amount Spent')
plt.legend()
